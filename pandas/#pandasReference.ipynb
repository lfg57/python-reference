# %% [markdown]
# # pandas

# %% [markdown]
# ## Overview

# %% [markdown]
# [pandas](https://pandas.pydata.org/) is a library written for Python, providing high-performance, easy-to-use data structures and data analysis tools, including operations for manipulating numerical tables and time series.

# %% [markdown]
# The most up-to-date **pandas documentation** can be found at [pandas documentation — pandas 1.0.1 documentation](https://pandas.pydata.org/docs/). It includes a user guide, full reference documentation, links to tutorials, and more.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
